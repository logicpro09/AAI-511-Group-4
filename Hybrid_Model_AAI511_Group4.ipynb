# %% [markdown]
# <a href="https://colab.research.google.com/github/logicpro09/AAI-511-Group-4/blob/main/Hybrid_Model_AAI511_Group4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Masking
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
import re

# load data
X = pd.read_csv("/content/drive/MyDrive/lstm_data.csv", index_col=0)
y = pd.read_csv("/content/drive/MyDrive/labels.csv", index_col=0)

# prepare labels
y = y.reset_index()
y.columns = ['composer']
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y['composer'])
y_categorical = to_categorical(y_encoded)

# convert to float and process non-numeric values
def safe_float(val):
    try:
        return float(val)
    except:
        if isinstance(val, str):
            # Handle chord-like strings e.g., "11.2.4"
            if re.match(r'^(\d+\.)*\d+$', val):
                parts = list(map(int, val.split('.')))
                return sum(parts) / len(parts)
            # Handle notes like C#5, A3, etc.
            elif re.match(r'^[A-G](#|-)?\d$', val):
                note = val[:-1]
                octave = int(val[-1])
                note_map = {'C': 0, 'C#': 1, 'D': 2, 'D#': 3, 'E': 4, 'F': 5, 'F#': 6,
                            'G': 7, 'G#': 8, 'A': 9, 'A#': 10, 'B': 11}
                semitone = note_map.get(note.replace('-', '#'), 0) # Handle both - and # for flats/sharps
                return semitone + 12 * octave
        return np.nan # Return NaN for values that cannot be parsed

X_clean = X.applymap(safe_float)

# impute nans with median column
X_clean.fillna(X_clean.median(), inplace=True)

# normalize
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X_clean)

# reshape for cnn/lstm
X_reshaped = np.expand_dims(X_scaled, axis=-1)

# split
X_train, X_test, y_train, y_test = train_test_split(
    X_reshaped, y_categorical, test_size=0.2, random_state=42)

# CNN and LSTM Model
model = Sequential([
    Masking(mask_value=0.0, input_shape=(X_reshaped.shape[1], 1)),
    Conv1D(filters=128, kernel_size=5, activation='relu'),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),
    Conv1D(filters=64, kernel_size=3, activation='relu'),
    MaxPooling1D(pool_size=2),
    Dropout(0.3),
    LSTM(128, return_sequences=True),
    Dropout(0.3),
    LSTM(64),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dense(y_categorical.shape[1], activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# callbacks
callbacks = [
    EarlyStopping(patience=10, restore_best_weights=True),
    ReduceLROnPlateau(patience=5, factor=0.5, verbose=1)
]

# train
history = model.fit(X_train, y_train, validation_split=0.1,
                    epochs=100, batch_size=16, callbacks=callbacks)

# evaluate metrics
loss, accuracy = model.evaluate(X_test, y_test)
print(f"\nTest Accuracy: {accuracy:.4f}")

# model summary
model.summary()

# plot accuracy and loss
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.show()

# classification report
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)

print("\nClassification Report:")
print(classification_report(y_true, y_pred, target_names=label_encoder.classes_))

# confusion matrix
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_encoder.classes_)
disp.plot(cmap='Blues', values_format='d')
plt.title("Confusion Matrix")
plt.show()
# Out:
# Epoch 1/100
# /tmp/ipython-input-1630635024.py:46: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   X_clean = X.applymap(safe_float)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/masking.py:48: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/layer.py:965: UserWarning: Layer 'conv1d_3' (of type Conv1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.3007 - loss: 1.3656 - val_accuracy: 0.4545 - val_loss: 1.2364 - learning_rate: 0.0010
# Epoch 2/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.3741 - loss: 1.3044 - val_accuracy: 0.4610 - val_loss: 1.2905 - learning_rate: 0.0010
# Epoch 3/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.3577 - loss: 1.3261 - val_accuracy: 0.4805 - val_loss: 1.2532 - learning_rate: 0.0010
# Epoch 4/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.3712 - loss: 1.2932 - val_accuracy: 0.4935 - val_loss: 1.2148 - learning_rate: 0.0010
# Epoch 5/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.3995 - loss: 1.2472 - val_accuracy: 0.3442 - val_loss: 1.2807 - learning_rate: 0.0010
# Epoch 6/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.4039 - loss: 1.2636 - val_accuracy: 0.4805 - val_loss: 1.2145 - learning_rate: 0.0010
# Epoch 7/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.4000 - loss: 1.2407 - val_accuracy: 0.5065 - val_loss: 1.2017 - learning_rate: 0.0010
# Epoch 8/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.4305 - loss: 1.2415 - val_accuracy: 0.5065 - val_loss: 1.2101 - learning_rate: 0.0010
# Epoch 9/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.4390 - loss: 1.2214 - val_accuracy: 0.5260 - val_loss: 1.2004 - learning_rate: 0.0010
# Epoch 10/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.4374 - loss: 1.2472 - val_accuracy: 0.5130 - val_loss: 1.1846 - learning_rate: 0.0010
# Epoch 11/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.4452 - loss: 1.2092 - val_accuracy: 0.5390 - val_loss: 1.1372 - learning_rate: 0.0010
# Epoch 12/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.4816 - loss: 1.1758 - val_accuracy: 0.5584 - val_loss: 1.1572 - learning_rate: 0.0010
# Epoch 13/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.4688 - loss: 1.2122 - val_accuracy: 0.5519 - val_loss: 1.1226 - learning_rate: 0.0010
# Epoch 14/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5027 - loss: 1.1437 - val_accuracy: 0.5325 - val_loss: 1.1168 - learning_rate: 0.0010
# Epoch 15/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5174 - loss: 1.1067 - val_accuracy: 0.5649 - val_loss: 1.1097 - learning_rate: 0.0010
# Epoch 16/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5441 - loss: 1.1020 - val_accuracy: 0.4740 - val_loss: 1.1012 - learning_rate: 0.0010
# Epoch 17/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.4776 - loss: 1.1497 - val_accuracy: 0.5649 - val_loss: 1.0868 - learning_rate: 0.0010
# Epoch 18/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5443 - loss: 1.0743 - val_accuracy: 0.5584 - val_loss: 1.0764 - learning_rate: 0.0010
# Epoch 19/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5592 - loss: 1.0255 - val_accuracy: 0.6039 - val_loss: 1.0593 - learning_rate: 0.0010
# Epoch 20/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5818 - loss: 1.0299 - val_accuracy: 0.6104 - val_loss: 0.9754 - learning_rate: 0.0010
# Epoch 21/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5901 - loss: 0.9972 - val_accuracy: 0.5649 - val_loss: 1.0284 - learning_rate: 0.0010
# Epoch 22/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.5970 - loss: 0.9650 - val_accuracy: 0.6299 - val_loss: 0.9560 - learning_rate: 0.0010
# Epoch 23/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.5966 - loss: 0.9464 - val_accuracy: 0.6104 - val_loss: 1.0012 - learning_rate: 0.0010
# Epoch 24/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.6562 - loss: 0.8635 - val_accuracy: 0.6364 - val_loss: 0.9841 - learning_rate: 0.0010
# Epoch 25/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.6344 - loss: 0.9056 - val_accuracy: 0.6623 - val_loss: 0.9169 - learning_rate: 0.0010
# Epoch 26/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.6721 - loss: 0.8248 - val_accuracy: 0.6429 - val_loss: 0.9385 - learning_rate: 0.0010
# Epoch 27/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.6912 - loss: 0.7978 - val_accuracy: 0.6883 - val_loss: 0.8939 - learning_rate: 0.0010
# Epoch 28/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.6676 - loss: 0.8215 - val_accuracy: 0.7078 - val_loss: 0.8251 - learning_rate: 0.0010
# Epoch 29/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7236 - loss: 0.7362 - val_accuracy: 0.6558 - val_loss: 0.9453 - learning_rate: 0.0010
# Epoch 30/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7030 - loss: 0.7359 - val_accuracy: 0.6948 - val_loss: 0.8042 - learning_rate: 0.0010
# Epoch 31/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7300 - loss: 0.6820 - val_accuracy: 0.6169 - val_loss: 0.9252 - learning_rate: 0.0010
# Epoch 32/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7194 - loss: 0.7339 - val_accuracy: 0.6753 - val_loss: 0.7810 - learning_rate: 0.0010
# Epoch 33/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7379 - loss: 0.6855 - val_accuracy: 0.6883 - val_loss: 0.7387 - learning_rate: 0.0010
# Epoch 34/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7543 - loss: 0.6197 - val_accuracy: 0.6818 - val_loss: 0.8213 - learning_rate: 0.0010
# Epoch 35/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7409 - loss: 0.6453 - val_accuracy: 0.7143 - val_loss: 0.7155 - learning_rate: 0.0010
# Epoch 36/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7748 - loss: 0.6047 - val_accuracy: 0.7468 - val_loss: 0.6580 - learning_rate: 0.0010
# Epoch 37/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7480 - loss: 0.5957 - val_accuracy: 0.7273 - val_loss: 0.7043 - learning_rate: 0.0010
# Epoch 38/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7829 - loss: 0.5685 - val_accuracy: 0.7597 - val_loss: 0.6625 - learning_rate: 0.0010
# Epoch 39/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7853 - loss: 0.5593 - val_accuracy: 0.7078 - val_loss: 0.6810 - learning_rate: 0.0010
# Epoch 40/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7952 - loss: 0.5310 - val_accuracy: 0.7662 - val_loss: 0.6018 - learning_rate: 0.0010
# Epoch 41/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.7804 - loss: 0.5396 - val_accuracy: 0.7597 - val_loss: 0.6233 - learning_rate: 0.0010
# Epoch 42/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8038 - loss: 0.4920 - val_accuracy: 0.7922 - val_loss: 0.5768 - learning_rate: 0.0010
# Epoch 43/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8135 - loss: 0.4866 - val_accuracy: 0.7857 - val_loss: 0.5466 - learning_rate: 0.0010
# Epoch 44/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8136 - loss: 0.4695 - val_accuracy: 0.7857 - val_loss: 0.5739 - learning_rate: 0.0010
# Epoch 45/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8388 - loss: 0.4075 - val_accuracy: 0.7727 - val_loss: 0.6048 - learning_rate: 0.0010
# Epoch 46/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8164 - loss: 0.4999 - val_accuracy: 0.7727 - val_loss: 0.5642 - learning_rate: 0.0010
# Epoch 47/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8242 - loss: 0.4471 - val_accuracy: 0.7922 - val_loss: 0.5081 - learning_rate: 0.0010
# Epoch 48/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8557 - loss: 0.3778 - val_accuracy: 0.7987 - val_loss: 0.4777 - learning_rate: 0.0010
# Epoch 49/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8712 - loss: 0.3251 - val_accuracy: 0.8052 - val_loss: 0.4870 - learning_rate: 0.0010
# Epoch 50/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8452 - loss: 0.3650 - val_accuracy: 0.7987 - val_loss: 0.4257 - learning_rate: 0.0010
# Epoch 51/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8354 - loss: 0.4054 - val_accuracy: 0.8052 - val_loss: 0.4875 - learning_rate: 0.0010
# Epoch 52/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8673 - loss: 0.3441 - val_accuracy: 0.8506 - val_loss: 0.3400 - learning_rate: 0.0010
# Epoch 53/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8695 - loss: 0.3064 - val_accuracy: 0.8052 - val_loss: 0.4291 - learning_rate: 0.0010
# Epoch 54/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9080 - loss: 0.2512 - val_accuracy: 0.7468 - val_loss: 0.5713 - learning_rate: 0.0010
# Epoch 55/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8712 - loss: 0.3257 - val_accuracy: 0.8182 - val_loss: 0.4408 - learning_rate: 0.0010
# Epoch 56/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8799 - loss: 0.3134 - val_accuracy: 0.8571 - val_loss: 0.3202 - learning_rate: 0.0010
# Epoch 57/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8701 - loss: 0.3441 - val_accuracy: 0.8377 - val_loss: 0.3762 - learning_rate: 0.0010
# Epoch 58/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8368 - loss: 0.3748 - val_accuracy: 0.8571 - val_loss: 0.3673 - learning_rate: 0.0010
# Epoch 59/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8733 - loss: 0.3335 - val_accuracy: 0.8506 - val_loss: 0.3318 - learning_rate: 0.0010
# Epoch 60/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8799 - loss: 0.3051 - val_accuracy: 0.8247 - val_loss: 0.3602 - learning_rate: 0.0010
# Epoch 61/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8945 - loss: 0.2734 - val_accuracy: 0.8636 - val_loss: 0.3139 - learning_rate: 0.0010
# Epoch 62/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9004 - loss: 0.2483 - val_accuracy: 0.8701 - val_loss: 0.3188 - learning_rate: 0.0010
# Epoch 63/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9084 - loss: 0.2311 - val_accuracy: 0.8636 - val_loss: 0.4689 - learning_rate: 0.0010
# Epoch 64/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8779 - loss: 0.3069 - val_accuracy: 0.8701 - val_loss: 0.3508 - learning_rate: 0.0010
# Epoch 65/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8876 - loss: 0.2850 - val_accuracy: 0.8831 - val_loss: 0.3344 - learning_rate: 0.0010
# Epoch 66/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9087 - loss: 0.2354 - val_accuracy: 0.9221 - val_loss: 0.2679 - learning_rate: 0.0010
# Epoch 67/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.8863 - loss: 0.3040 - val_accuracy: 0.9156 - val_loss: 0.2629 - learning_rate: 0.0010
# Epoch 68/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9126 - loss: 0.2217 - val_accuracy: 0.9026 - val_loss: 0.3070 - learning_rate: 0.0010
# Epoch 69/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9240 - loss: 0.2260 - val_accuracy: 0.9091 - val_loss: 0.2266 - learning_rate: 0.0010
# Epoch 70/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9082 - loss: 0.2086 - val_accuracy: 0.8961 - val_loss: 0.2354 - learning_rate: 0.0010
# Epoch 71/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9367 - loss: 0.1711 - val_accuracy: 0.8766 - val_loss: 0.3276 - learning_rate: 0.0010
# Epoch 72/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9068 - loss: 0.2527 - val_accuracy: 0.9351 - val_loss: 0.2186 - learning_rate: 0.0010
# Epoch 73/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9183 - loss: 0.2027 - val_accuracy: 0.8636 - val_loss: 0.4060 - learning_rate: 0.0010
# Epoch 74/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9127 - loss: 0.2168 - val_accuracy: 0.8701 - val_loss: 0.3113 - learning_rate: 0.0010
# Epoch 75/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9153 - loss: 0.2097 - val_accuracy: 0.9286 - val_loss: 0.2299 - learning_rate: 0.0010
# Epoch 76/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9310 - loss: 0.2122 - val_accuracy: 0.9091 - val_loss: 0.2813 - learning_rate: 0.0010
# Epoch 77/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9320 - loss: 0.1690 - val_accuracy: 0.9416 - val_loss: 0.1625 - learning_rate: 0.0010
# Epoch 78/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9358 - loss: 0.1810 - val_accuracy: 0.9351 - val_loss: 0.1914 - learning_rate: 0.0010
# Epoch 79/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9353 - loss: 0.1573 - val_accuracy: 0.8961 - val_loss: 0.2136 - learning_rate: 0.0010
# Epoch 80/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9426 - loss: 0.1538 - val_accuracy: 0.9416 - val_loss: 0.1764 - learning_rate: 0.0010
# Epoch 81/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9457 - loss: 0.1595 - val_accuracy: 0.9286 - val_loss: 0.1819 - learning_rate: 0.0010
# Epoch 82/100
# 85/87 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9390 - loss: 0.1716
# Epoch 82: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9393 - loss: 0.1712 - val_accuracy: 0.9286 - val_loss: 0.2105 - learning_rate: 0.0010
# Epoch 83/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9550 - loss: 0.1350 - val_accuracy: 0.9351 - val_loss: 0.1524 - learning_rate: 5.0000e-04
# Epoch 84/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9625 - loss: 0.0986 - val_accuracy: 0.9545 - val_loss: 0.1333 - learning_rate: 5.0000e-04
# Epoch 85/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9655 - loss: 0.0910 - val_accuracy: 0.9610 - val_loss: 0.0979 - learning_rate: 5.0000e-04
# Epoch 86/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9755 - loss: 0.0729 - val_accuracy: 0.9610 - val_loss: 0.1251 - learning_rate: 5.0000e-04
# Epoch 87/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9680 - loss: 0.1015 - val_accuracy: 0.9740 - val_loss: 0.0962 - learning_rate: 5.0000e-04
# Epoch 88/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9697 - loss: 0.0784 - val_accuracy: 0.9675 - val_loss: 0.1234 - learning_rate: 5.0000e-04
# Epoch 89/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9639 - loss: 0.1074 - val_accuracy: 0.9740 - val_loss: 0.1273 - learning_rate: 5.0000e-04
# Epoch 90/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9707 - loss: 0.0887 - val_accuracy: 0.9870 - val_loss: 0.1092 - learning_rate: 5.0000e-04
# Epoch 91/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9756 - loss: 0.0883 - val_accuracy: 0.9740 - val_loss: 0.1009 - learning_rate: 5.0000e-04
# Epoch 92/100
# 86/87 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9665 - loss: 0.0804
# Epoch 92: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9665 - loss: 0.0805 - val_accuracy: 0.9675 - val_loss: 0.1049 - learning_rate: 5.0000e-04
# Epoch 93/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9778 - loss: 0.0639 - val_accuracy: 0.9870 - val_loss: 0.0666 - learning_rate: 2.5000e-04
# Epoch 94/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9770 - loss: 0.0571 - val_accuracy: 0.9870 - val_loss: 0.0616 - learning_rate: 2.5000e-04
# Epoch 95/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9771 - loss: 0.0600 - val_accuracy: 0.9870 - val_loss: 0.0720 - learning_rate: 2.5000e-04
# Epoch 96/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9766 - loss: 0.0570 - val_accuracy: 0.9610 - val_loss: 0.0982 - learning_rate: 2.5000e-04
# Epoch 97/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9868 - loss: 0.0431 - val_accuracy: 0.9805 - val_loss: 0.0823 - learning_rate: 2.5000e-04
# Epoch 98/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9832 - loss: 0.0475 - val_accuracy: 0.9870 - val_loss: 0.0639 - learning_rate: 2.5000e-04
# Epoch 99/100
# 85/87 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9808 - loss: 0.0524
# Epoch 99: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9809 - loss: 0.0523 - val_accuracy: 0.9870 - val_loss: 0.0623 - learning_rate: 2.5000e-04
# Epoch 100/100
# 87/87 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9949 - loss: 0.0282 - val_accuracy: 0.9870 - val_loss: 0.0720 - learning_rate: 1.2500e-04
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9628 - loss: 0.1853
#
# Test Accuracy: 0.9662
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ masking_5 (Masking)             │ (None, 99, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 95, 128)        │           768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 47, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 47, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 45, 64)         │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 22, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 22, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_14 (LSTM)                  │ (None, 22, 128)        │        98,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ (None, 22, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_15 (LSTM)                  │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 534,158 (2.04 MB)
#  Trainable params: 178,052 (695.52 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 356,106 (1.36 MB)
# WARNING:tensorflow:5 out of the last 13 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a7aac4bff60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Bach       0.97      0.96      0.97       103
#    Beethoven       0.95      1.00      0.98        98
#       Chopin       0.98      0.95      0.96       115
#       Mozart       0.96      0.96      0.96        69
#
#     accuracy                           0.97       385
#    macro avg       0.97      0.97      0.97       385
# weighted avg       0.97      0.97      0.97       385
